# %% [markdown]
# # ACCESS TO THE RESULTS

# %% [markdown]
# ## Importing Section

# %%
# -*- coding: utf-8 -*-
"""
Created on Mon Jun 25 15:57:07 2018

@author: a.iacono
"""
import sqlitedict 
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# ## Preprocessing Section

# %% [markdown]
# ### Setting the name of the file that contain the database

# %%
name='opti_g_50'

# %% [markdown]
# ### Creating a dictonary from the database

# %% [markdown]
# The print line just show us the number of the iterations and the respective keys for each iteration.

# %%
db = sqlitedict.SqliteDict( name, 'iterations' )
print( list( db.keys() ) )
# Out:
# ['rank0:COBYLA|0|root|1', 'rank0:COBYLA|1|root|2', 'rank0:COBYLA|2|root|3', 'rank0:COBYLA|3|root|4', 'rank0:COBYLA|4|root|5', 'rank0:COBYLA|5|root|6', 'rank0:COBYLA|6|root|7', 'rank0:COBYLA|7|root|8', 'rank0:COBYLA|8|root|9', 'rank0:COBYLA|9|root|10', 'rank0:COBYLA|10|root|11', 'rank0:COBYLA|11|root|12', 'rank0:COBYLA|12|root|13', 'rank0:COBYLA|13|root|14', 'rank0:COBYLA|14|root|15', 'rank0:COBYLA|15|root|16', 'rank0:COBYLA|16|root|17', 'rank0:COBYLA|17|root|18', 'rank0:COBYLA|18|root|19', 'rank0:COBYLA|19|root|20', 'rank0:COBYLA|20|root|21', 'rank0:COBYLA|21|root|22', 'rank0:COBYLA|22|root|23', 'rank0:COBYLA|23|root|24', 'rank0:COBYLA|24|root|25', 'rank0:COBYLA|25|root|26', 'rank0:COBYLA|26|root|27', 'rank0:COBYLA|27|root|28', 'rank0:COBYLA|28|root|29', 'rank0:COBYLA|29|root|30', 'rank0:COBYLA|30|root|31', 'rank0:COBYLA|31|root|32', 'rank0:COBYLA|32|root|33', 'rank0:COBYLA|33|root|34', 'rank0:COBYLA|34|root|35', 'rank0:COBYLA|35|root|36', 'rank0:COBYLA|36|root|37', 'rank0:COBYLA|37|root|38', 'rank0:COBYLA|38|root|39', 'rank0:COBYLA|39|root|40', 'rank0:COBYLA|40|root|41', 'rank0:COBYLA|41|root|42', 'rank0:COBYLA|42|root|43', 'rank0:COBYLA|43|root|44', 'rank0:COBYLA|44|root|45', 'rank0:COBYLA|45|root|46', 'rank0:COBYLA|46|root|47', 'rank0:COBYLA|47|root|48', 'rank0:COBYLA|48|root|49', 'rank0:COBYLA|49|root|50', 'rank0:COBYLA|50|root|51', 'rank0:COBYLA|51|root|52', 'rank0:COBYLA|52|root|53', 'rank0:COBYLA|53|root|54', 'rank0:COBYLA|54|root|55', 'rank0:COBYLA|55|root|56', 'rank0:COBYLA|56|root|57', 'rank0:COBYLA|57|root|58', 'rank0:COBYLA|58|root|59', 'rank0:COBYLA|59|root|60', 'rank0:COBYLA|60|root|61', 'rank0:COBYLA|61|root|62', 'rank0:COBYLA|62|root|63', 'rank0:COBYLA|63|root|64', 'rank0:COBYLA|64|root|65', 'rank0:COBYLA|65|root|66', 'rank0:COBYLA|66|root|67', 'rank0:COBYLA|67|root|68', 'rank0:COBYLA|68|root|69', 'rank0:COBYLA|69|root|70', 'rank0:COBYLA|70|root|71', 'rank0:COBYLA|71|root|72', 'rank0:COBYLA|72|root|73', 'rank0:COBYLA|73|root|74', 'rank0:COBYLA|74|root|75', 'rank0:COBYLA|75|root|76', 'rank0:COBYLA|76|root|77', 'rank0:COBYLA|77|root|78', 'rank0:COBYLA|78|root|79', 'rank0:COBYLA|79|root|80', 'rank0:COBYLA|80|root|81', 'rank0:COBYLA|81|root|82', 'rank0:COBYLA|82|root|83', 'rank0:COBYLA|83|root|84', 'rank0:COBYLA|84|root|85', 'rank0:COBYLA|85|root|86', 'rank0:COBYLA|86|root|87', 'rank0:COBYLA|87|root|88', 'rank0:COBYLA|88|root|89', 'rank0:COBYLA|89|root|90', 'rank0:COBYLA|90|root|91', 'rank0:COBYLA|91|root|92', 'rank0:COBYLA|92|root|93', 'rank0:COBYLA|93|root|94', 'rank0:COBYLA|94|root|95', 'rank0:COBYLA|95|root|96', 'rank0:COBYLA|96|root|97', 'rank0:COBYLA|97|root|98', 'rank0:COBYLA|98|root|99', 'rank0:COBYLA|99|root|100', 'rank0:COBYLA|100|root|101', 'rank0:COBYLA|101|root|102', 'rank0:COBYLA|102|root|103', 'rank0:COBYLA|103|root|104', 'rank0:COBYLA|104|root|105', 'rank0:COBYLA|105|root|106', 'rank0:COBYLA|106|root|107', 'rank0:COBYLA|107|root|108', 'rank0:COBYLA|108|root|109', 'rank0:COBYLA|109|root|110', 'rank0:COBYLA|110|root|111', 'rank0:COBYLA|111|root|112', 'rank0:COBYLA|112|root|113', 'rank0:COBYLA|113|root|114', 'rank0:COBYLA|114|root|115', 'rank0:COBYLA|115|root|116', 'rank0:COBYLA|116|root|117', 'rank0:COBYLA|117|root|118', 'rank0:COBYLA|118|root|119', 'rank0:COBYLA|119|root|120', 'rank0:COBYLA|120|root|121', 'rank0:COBYLA|121|root|122', 'rank0:COBYLA|122|root|123', 'rank0:COBYLA|123|root|124', 'rank0:COBYLA|124|root|125', 'rank0:COBYLA|125|root|126', 'rank0:COBYLA|126|root|127', 'rank0:COBYLA|127|root|128', 'rank0:COBYLA|128|root|129', 'rank0:COBYLA|129|root|130', 'rank0:COBYLA|130|root|131', 'rank0:COBYLA|131|root|132', 'rank0:COBYLA|132|root|133', 'rank0:COBYLA|133|root|134', 'rank0:COBYLA|134|root|135', 'rank0:COBYLA|135|root|136', 'rank0:COBYLA|136|root|137', 'rank0:COBYLA|137|root|138', 'rank0:COBYLA|138|root|139', 'rank0:COBYLA|139|root|140', 'rank0:COBYLA|140|root|141', 'rank0:COBYLA|141|root|142', 'rank0:COBYLA|142|root|143', 'rank0:COBYLA|143|root|144', 'rank0:COBYLA|144|root|145', 'rank0:COBYL ...

# %% [markdown]
# ### Defining the number of the iteration and the x-axis for the graph

# %%
n=len(db)
x=np.arange(0,n)

# %% [markdown]
# ### Creating the empy vector to save all the value for each iteration of the variables of interest

# %%
cd=np.array([])
g=np.array([])
m=np.array([])
vm=np.array([])
cl=np.array([])
a=np.array([])
vms=np.array([])
t1=np.array([])
t2=np.array([])
t3=np.array([])
t4=np.array([])
t5=np.array([])
t6=np.array([])
t7=np.array([])
t8=np.array([])
t9=np.array([])
t10=np.array([])
t11=np.array([])
t12=np.array([])

# %% [markdown]
# ### Extrapoling the dictonary of the first iteration to have access to some value like the yield stress

# %%
data = db['rank0:COBYLA|0|root|1']
c = data['Unknowns']

# %% [markdown]
# ### Determinating the value of the lift and stress constraint

# %%
con_l=(c['W']/(0.5*c['rho_a']*c['V']**2*c['Sw']))*np.ones(n)
con_s=c['sigma_y']*np.ones(n)

# %% [markdown]
# ### Accessing to the value for each iteration

# %% [markdown]
# As first we obtain a database for each iteration, the print command it's just to have a feedback on the runtime.
#
# From the Data dictonary we can collect all the data in refernce at the variables of interest, and append it to the vector created in the settings section.

# %%
for j in range(0,n):
         data = db['rank0:COBYLA|'+str(j)+'|root|'+str(j+1)]
         print('rank0:COBYLA|'+str(j)+'|root|'+str(j+1))
#         u = data['Parameters']
         c = data['Unknowns']
         g = np.append(g,c['G'])
         cd =np.append(cd, c['CDi'])
         a = np.append(a,c['alpha'])
         m = np.append(m,c['mass'])
         vms = max(c['VMStress'])
         vm = np.append(vm,vms)
         cl = np.append(cl, c['CL'])
         t = c['t']
         t1 = np.append(t1,t[0])
         t2 = np.append(t2,t[1])
         t3 = np.append(t3,t[2])
         t4 = np.append(t4,t[3])
         t5 = np.append(t5,t[4])
         t6 = np.append(t6,t[5])
         t7 = np.append(t7,t[6])
         t8 = np.append(t8,t[7])
         t9 = np.append(t9,t[8])
         t10 = np.append(t10,t[9])
         t11 = np.append(t11,t[10])
         t12 = np.append(t12,t[11])
# Out:
# rank0:COBYLA|0|root|1
# rank0:COBYLA|1|root|2
# rank0:COBYLA|2|root|3
# rank0:COBYLA|3|root|4
# rank0:COBYLA|4|root|5
# rank0:COBYLA|5|root|6
# rank0:COBYLA|6|root|7
# rank0:COBYLA|7|root|8
# rank0:COBYLA|8|root|9
# rank0:COBYLA|9|root|10
# rank0:COBYLA|10|root|11
# rank0:COBYLA|11|root|12
# rank0:COBYLA|12|root|13
# rank0:COBYLA|13|root|14
# rank0:COBYLA|14|root|15
# rank0:COBYLA|15|root|16
# rank0:COBYLA|16|root|17
# rank0:COBYLA|17|root|18
# rank0:COBYLA|18|root|19
# rank0:COBYLA|19|root|20
# rank0:COBYLA|20|root|21
# rank0:COBYLA|21|root|22
# rank0:COBYLA|22|root|23
# rank0:COBYLA|23|root|24
# rank0:COBYLA|24|root|25
# rank0:COBYLA|25|root|26
# rank0:COBYLA|26|root|27
# rank0:COBYLA|27|root|28
# rank0:COBYLA|28|root|29
# rank0:COBYLA|29|root|30
# rank0:COBYLA|30|root|31
# rank0:COBYLA|31|root|32
# rank0:COBYLA|32|root|33
# rank0:COBYLA|33|root|34
# rank0:COBYLA|34|root|35
# rank0:COBYLA|35|root|36
# rank0:COBYLA|36|root|37
# rank0:COBYLA|37|root|38
# rank0:COBYLA|38|root|39
# rank0:COBYLA|39|root|40
# rank0:COBYLA|40|root|41
# rank0:COBYLA|41|root|42
# rank0:COBYLA|42|root|43
# rank0:COBYLA|43|root|44
# rank0:COBYLA|44|root|45
# rank0:COBYLA|45|root|46
# rank0:COBYLA|46|root|47
# rank0:COBYLA|47|root|48
# rank0:COBYLA|48|root|49
# rank0:COBYLA|49|root|50
# rank0:COBYLA|50|root|51
# rank0:COBYLA|51|root|52
# rank0:COBYLA|52|root|53
# rank0:COBYLA|53|root|54
# rank0:COBYLA|54|root|55
# rank0:COBYLA|55|root|56
# rank0:COBYLA|56|root|57
# rank0:COBYLA|57|root|58
# rank0:COBYLA|58|root|59
# rank0:COBYLA|59|root|60
# rank0:COBYLA|60|root|61
# rank0:COBYLA|61|root|62
# rank0:COBYLA|62|root|63
# rank0:COBYLA|63|root|64
# rank0:COBYLA|64|root|65
# rank0:COBYLA|65|root|66
# rank0:COBYLA|66|root|67
# rank0:COBYLA|67|root|68
# rank0:COBYLA|68|root|69
# rank0:COBYLA|69|root|70
# rank0:COBYLA|70|root|71
# rank0:COBYLA|71|root|72
# rank0:COBYLA|72|root|73
# rank0:COBYLA|73|root|74
# rank0:COBYLA|74|root|75
# rank0:COBYLA|75|root|76
# rank0:COBYLA|76|root|77
# rank0:COBYLA|77|root|78
# rank0:COBYLA|78|root|79
# rank0:COBYLA|79|root|80
# rank0:COBYLA|80|root|81
# rank0:COBYLA|81|root|82
# rank0:COBYLA|82|root|83
# rank0:COBYLA|83|root|84
# rank0:COBYLA|84|root|85
# rank0:COBYLA|85|root|86
# rank0:COBYLA|86|root|87
# rank0:COBYLA|87|root|88
# rank0:COBYLA|88|root|89
# rank0:COBYLA|89|root|90
# rank0:COBYLA|90|root|91
# rank0:COBYLA|91|root|92
# rank0:COBYLA|92|root|93
# rank0:COBYLA|93|root|94
# rank0:COBYLA|94|root|95
# rank0:COBYLA|95|root|96
# rank0:COBYLA|96|root|97
# rank0:COBYLA|97|root|98
# rank0:COBYLA|98|root|99
# rank0:COBYLA|99|root|100
# rank0:COBYLA|100|root|101
# rank0:COBYLA|101|root|102
# rank0:COBYLA|102|root|103
# rank0:COBYLA|103|root|104
# rank0:COBYLA|104|root|105
# rank0:COBYLA|105|root|106
# rank0:COBYLA|106|root|107
# rank0:COBYLA|107|root|108
# rank0:COBYLA|108|root|109
# rank0:COBYLA|109|root|110
# rank0:COBYLA|110|root|111
# rank0:COBYLA|111|root|112
# rank0:COBYLA|112|root|113
# rank0:COBYLA|113|root|114
# rank0:COBYLA|114|root|115
# rank0:COBYLA|115|root|116
# rank0:COBYLA|116|root|117
# rank0:COBYLA|117|root|118
# rank0:COBYLA|118|root|119
# rank0:COBYLA|119|root|120
# rank0:COBYLA|120|root|121
# rank0:COBYLA|121|root|122
# rank0:COBYLA|122|root|123
# rank0:COBYLA|123|root|124
# rank0:COBYLA|124|root|125
# rank0:COBYLA|125|root|126
# rank0:COBYLA|126|root|127
# rank0:COBYLA|127|root|128
# rank0:COBYLA|128|root|129
# rank0:COBYLA|129|root|130
# rank0:COBYLA|130|root|131
# rank0:COBYLA|131|root|132
# rank0:COBYLA|132|root|133
# rank0:COBYLA|133|root|134
# rank0:COBYLA|134|root|135
# rank0:COBYLA|135|root|136
# rank0:COBYLA|136|root|137
# rank0:COBYLA|137|root|138
# rank0:COBYLA|138|root|139
# rank0:COBYLA|139|root|140
# rank0:COBYLA|140|root|141
# rank0:COBYLA|141|root|142
# rank0:COBYLA|142|root|143
# rank0:COBYLA|143|root|144
# rank0:COBYLA|144|root|145
# rank0:COBYLA|145|root|146
# rank0:COBYLA|146|root|147
# rank0:COBYLA|147|root|148
# rank0:COBYLA|148|root|149
# rank0:COBYLA|149|root|150
# rank0:COBYLA|150|root|151
# rank0:COBYLA|151|root|152
# rank0:COBYLA|152|root|153
# rank0:COBYLA|153|root|154
# rank0:COBYLA|154|root|155
# rank0:COBYLA|155|root|156
# rank0:COBYLA|156|root|157
# rank0:COBYLA|157|root|158
# rank0:COBYLA|158|root|159
# rank0:COBYLA|159|root|160
# rank0:COBYLA|160|root|161
# rank0:COBYLA|161|root|162
# rank0:COBYLA|162|root|163
# rank0:COBYLA|163|root|164
# rank0:COBYLA|164|root|165
# rank0:COBYLA|165|root|166
# rank0:COBYLA|166|root|167
# rank0:COBYLA|167|root|168
# rank0:COBYLA|168|root|169
# rank0:COBYLA|169|root|170
# rank0:COBYLA|170|root|171
# rank0:COBYLA|171|root|172
# rank0:COBYLA|172|root|173
# rank0:COBYLA|173|root|174
# rank0:COBYLA|174|root|175
# rank0:COBYLA|175|root|176
# rank0:COBYLA|176|root|177
# rank0:COBYLA|177|root|178
# rank0:COBYLA|178|root|179
# rank0:COBYLA|179|root|180
# rank0:COBYLA|180|root|181
# rank0:COBYLA|181|root|182
# rank0:COBYLA|182|root|183
# rank0:COBYLA|183|root|184
# rank0:COBYLA|184|root|185
# rank0:COBYLA|185|root|186
# rank0:COBYLA|186|root|187
# rank0:COBYLA|187|root|188
# rank0:COBYLA|188|root|189
# rank0:COBYLA|189|root|190
# rank0:COBYLA|190|root|191
# rank0:COBYLA|191|root|192
# rank0:COBYLA|192|root|193
# rank0:COBYLA|193|root|194
# rank0:COBYLA|194|root|195
# rank0:COBYLA|195|root|196
# rank0:COBYLA|196|root|197
# rank0:COBYLA|197|root|198
# rank0:COBYLA|198|root|199
# rank0:COBYLA|199|root|200
# rank0:COBYLA|200|root|201

# %% [markdown]
# ## Print Results

# %% [markdown]
# Here we are printing all the graph of the variation of the variables for each iteration.
#
# The script is also set to save the plot as jpg files in the code folder.

# %%
# %matplotlib inline
# a command to print the graph in this page ( need just for the jupyter version)

# %%
fig, axes = plt.subplots(1, 3, figsize=(12, 4))
axes[1].grid (True)
axes[1].set_xlabel('iteration', fontsize=14)
axes[1].plot(x,vm)
axes[1].plot(x,con_s)
axes[1].set_title("VonMises")
axes[2].set_xlabel('iteration', fontsize=14)
axes[2].grid (True)
axes[2].plot(x,g)
axes[2].plot(x,con_s)
axes[2].set_title("G")
axes[0].plot(x,a)
axes[0].set_title("alpha")
axes[0].grid (True)
axes[0].set_xlabel('iteration', fontsize=14)
#axes[2].plot(x,32vms)
#axes[2].set_title("VonMises Stresses")
plt.savefig(name+'_1',dpi=1000, bbox_inches='tight')
plt.show()
fig, axes = plt.subplots(1, 3, figsize=(12, 4))

axes[1].grid (True)
axes[1].set_xlabel('iteration', fontsize=14)
axes[1].plot(x,cd)
axes[1].set_title("CDi")
axes[2].set_xlabel('iteration', fontsize=14)
axes[2].grid (True)
axes[2].plot(x,cl)
axes[2].plot(x,con_l)
axes[2].set_title("CL")
axes[0].plot(x,m)
axes[0].set_title("Mass")
axes[0].grid (True)
axes[0].set_xlabel('iteration', fontsize=14)
#axes[2].plot(x,32vms)
#axes[2].set_title("VonMises Stresses")
plt.savefig(name+'_2',dpi=1000, bbox_inches='tight')
plt.show()
plt.plot(x,t1,label='t[1]')
plt.plot(x,t2,label='t[2]')
plt.plot(x,t3,label='t[3]')
plt.plot(x,t4,label='t[4]')
plt.plot(x,t5,label='t[5]')
plt.plot(x,t6,label='t[6]')
plt.plot(x,t7,label='t[7]')
plt.plot(x,t8,label='t[8]')
plt.plot(x,t9,label='t[9]')
plt.plot(x,t10,label='t[10]')
plt.plot(x,t11,label='t[11]')
plt.plot(x,t12,label='t[12]')
plt.grid(True)
plt.xlabel('iteration', fontsize=14)
plt.ylabel('thickness', fontsize=14)
plt.legend(loc='upper center', bbox_to_anchor=(0.5, -0.05),
          fancybox=True, shadow=True, ncol=5)
plt.savefig(name+'_3',dpi=1000, bbox_inches='tight')
